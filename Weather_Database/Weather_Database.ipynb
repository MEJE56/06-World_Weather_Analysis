# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json

# Import the API key
from config import weather_api_key

# Use the citipy module to determine city/country based on latitude and longitude
from citipy import citipy

# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Calling URL for Weather Map API
url = 'http://api.openweathermap.org/data/2.5/weather?' + '&units=Imperial' + '&APPID=' + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather date
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city.replace(' ','+')
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({'City': city,
                          'Country': city_country,
                          'Date': city_date,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind, 'Current Description': city_description})

        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping..." + city)
        pass

    # Indicate that Data Loading is complete.

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lorengau
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | ambulu
# Processing Record 4 of Set 1 | chuy
# City not found. Skipping...taolanaro
# Processing Record 5 of Set 1 | taolanaro
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | port lincoln
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | tutoia
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | hingatungan
# City not found. Skipping...tasbuget
# Processing Record 14 of Set 1 | tasbuget
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | broken hill
# Processing Record 18 of Set 1 | naifaru
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | poum
# Processing Record 21 of Set 1 | nelson bay
# Processing Record 22 of Set 1 | itapirapua
# Processing Record 23 of Set 1 | sayyan
# Processing Record 24 of Set 1 | kununurra
# City not found. Skipping...illoqqortoormiut
# Processing Record 25 of Set 1 | illoqqortoormiut
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | kiunga
# Processing Record 29 of Set 1 | kenai
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | korla
# Processing Record 33 of Set 1 | ushuaia
# City not found. Skipping...hihifo
# Processing Record 34 of Set 1 | hihifo
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | belmonte
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | barbastro
# Processing Record 39 of Set 1 | irati
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | fayaoue
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | virginia beach
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | khairpur
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | vilhena
# Processing Record 50 of Set 1 | vallenar
# Processing Record 1 of Set 2 | omemee
# Processing Record 2 of Set 2 | santa rosa
# City not found. Skipping...sentyabrskiy
# Processing Record 3 of Set 2 | sentyabrskiy
# Processing Record 4 of Set 2 | ahipara
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | bintulu
# Processing Record 7 of Set 2 | dallas
# Processing Record 8 of Set 2 | camocim
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | sioux lookout
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | dongli
# Processing Record 16 of Set 2 | ayan
# Processing Record 17 of Set 2 | biak
# Processing Record 18 of Set 2 | miyako
# City not found. Skipping...nizhneyansk
# Processing Record 19 of Set 2 | nizhneyansk
# Processing Record 20 of Set 2 | piacabucu
# Processing Record 21 of Set 2 | alekseyevka
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | amapa
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | namatanai
# Processing Record 28 of Set 2 | lasa
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | mogadishu
# Processing Record 32 of Set 2 | ergani
# Processing Record 33 of Set 2 | odweyne
# Processing Record 34 of Set 2 | naze
# Processing Record 35 of Set 2 | paita
# Processing Record 36 of Set 2 | tautira
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | tirlyanskiy
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | puerto del rosario
# Processing Record 41 of Set 2 | caravelas
# Processing Record 42 of Set 2 | kenora
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | harstad
# Processing Record 46 of Set 2 | oranjemund
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | alofi
# Processing Record 1 of Set 3 | general pico
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | san cristobal
# Processing Record 4 of Set 3 | cassilandia
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | tarko-sale
# Processing Record 7 of Set 3 | sinazongwe
# City not found. Skipping...belushya guba
# Processing Record 8 of Set 3 | belushya guba
# Processing Record 9 of Set 3 | krosno odrzanskie
# Processing Record 10 of Set 3 | houma
# Processing Record 11 of Set 3 | alyangula
# Processing Record 12 of Set 3 | xuddur
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | mastic beach
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | barstow
# Processing Record 22 of Set 3 | ballina
# Processing Record 23 of Set 3 | puerto ayacucho
# Processing Record 24 of Set 3 | laguna
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | freeport
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | am timan
# Processing Record 30 of Set 3 | quilmana
# Processing Record 31 of Set 3 | sinnamary
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | torit
# Processing Record 34 of Set 3 | vostok
# Processing Record 35 of Set 3 | abu dhabi
# Processing Record 36 of Set 3 | grand forks
# City not found. Skipping...umzimvubu
# Processing Record 37 of Set 3 | umzimvubu
# City not found. Skipping...mrirt
# Processing Record 38 of Set 3 | mrirt
# Processing Record 39 of Set 3 | burla
# Processing Record 40 of Set 3 | ananas
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | kautokeino
# Processing Record 43 of Set 3 | untsukul
# Processing Record 44 of Set 3 | trairi
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | mount pleasant
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | patancheru
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | rantepao
# Processing Record 2 of Set 4 | miri
# Processing Record 3 of Set 4 | egvekinot
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | bireun
# Processing Record 6 of Set 4 | srivardhan
# Processing Record 7 of Set 4 | balezino
# Processing Record 8 of Set 4 | ler
# Processing Record 9 of Set 4 | la seyne-sur-mer
# City not found. Skipping...mys shmidta
# Processing Record 10 of Set 4 | mys shmidta
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | jaciara
# Processing Record 14 of Set 4 | rocha
# Processing Record 15 of Set 4 | pacific grove
# City not found. Skipping...alotau
# Processing Record 16 of Set 4 | alotau
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | keetmanshoop
# Processing Record 19 of Set 4 | angoche
# Processing Record 20 of Set 4 | sekoma
# Processing Record 21 of Set 4 | barabinsk
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | college
# Processing Record 24 of Set 4 | mehamn
# Processing Record 25 of Set 4 | abonnema
# Processing Record 26 of Set 4 | jeremie
# Processing Record 27 of Set 4 | hermanus
# City not found. Skipping...barbar
# Processing Record 28 of Set 4 | barbar
# Processing Record 29 of Set 4 | sola
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | kangaatsiaq
# Processing Record 32 of Set 4 | hit
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | fredericton
# City not found. Skipping...marcona
# Processing Record 35 of Set 4 | marcona
# Processing Record 36 of Set 4 | kemijarvi
# Processing Record 37 of Set 4 | yablonovskiy
# City not found. Skipping...grand river south east
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...samalaeulu
# Processing Record 39 of Set 4 | samalaeulu
# Processing Record 40 of Set 4 | lucapa
# Processing Record 41 of Set 4 | bodden town
# City not found. Skipping...amderma
# Processing Record 42 of Set 4 | amderma
# Processing Record 43 of Set 4 | teya
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | capanema
# Processing Record 46 of Set 4 | nemuro
# Processing Record 47 of Set 4 | black river
# Processing Record 48 of Set 4 | torbay
# City not found. Skipping...attawapiskat
# Processing Record 49 of Set 4 | attawapiskat
# Processing Record 50 of Set 4 | riyadh
# Processing Record 1 of Set 5 | hilo
# Processing Record 2 of Set 5 | portobelo
# Processing Record 3 of Set 5 | brigantine
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | darhan
# Processing Record 6 of Set 5 | coihaique
# Processing Record 7 of Set 5 | kalat
# Processing Record 8 of Set 5 | khasan
# Processing Record 9 of Set 5 | phan thiet
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | turayf
# Processing Record 12 of Set 5 | mount gambier
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | paamiut
# Processing Record 15 of Set 5 | sosnovo
# City not found. Skipping...falealupo
# Processing Record 16 of Set 5 | falealupo
# Processing Record 17 of Set 5 | dwarka
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | severo-kurilsk
# Processing Record 20 of Set 5 | beloha
# Processing Record 21 of Set 5 | kruisfontein
# Processing Record 22 of Set 5 | cap-aux-meules
# Processing Record 23 of Set 5 | carnarvon
# Processing Record 24 of Set 5 | marshall
# Processing Record 25 of Set 5 | berezovyy
# Processing Record 26 of Set 5 | beringovskiy
# Processing Record 27 of Set 5 | katherine
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | bilma
# Processing Record 30 of Set 5 | san pedro
# Processing Record 31 of Set 5 | san javier
# Processing Record 32 of Set 5 | bilibino
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | yarada
# Processing Record 35 of Set 5 | bredasdorp
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | guymon
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | sao miguel do araguaia
# Processing Record 41 of Set 5 | charleville-mezieres
# Processing Record 42 of Set 5 | gijon
# Processing Record 43 of Set 5 | porto novo
# City not found. Skipping...yanchukan
# Processing Record 44 of Set 5 | yanchukan
# City not found. Skipping...juquila
# Processing Record 45 of Set 5 | juquila
# Processing Record 46 of Set 5 | zyryanka
# Processing Record 47 of Set 5 | garden city
# Processing Record 48 of Set 5 | richards bay
# Processing Record 49 of Set 5 | sistranda
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | riberalta
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | corlu
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | bay roberts
# Processing Record 6 of Set 6 | jiayuguan
# Processing Record 7 of Set 6 | governador valadares
# Processing Record 8 of Set 6 | inarcs
# City not found. Skipping...palabuhanratu
# Processing Record 9 of Set 6 | palabuhanratu
# Processing Record 10 of Set 6 | mersing
# Processing Record 11 of Set 6 | mar del plata
# Processing Record 12 of Set 6 | krasnoselkup
# Processing Record 13 of Set 6 | casablanca
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | hofn
# City not found. Skipping...bolungarvik
# Processing Record 16 of Set 6 | bolungarvik
# Processing Record 17 of Set 6 | dzaoudzi
# Processing Record 18 of Set 6 | saint-georges
# Processing Record 19 of Set 6 | bathsheba
# City not found. Skipping...barentsburg
# Processing Record 20 of Set 6 | barentsburg
# Processing Record 21 of Set 6 | vicuna
# Processing Record 22 of Set 6 | palmer
# Processing Record 23 of Set 6 | mazagao
# Processing Record 24 of Set 6 | hamilton
# Processing Record 25 of Set 6 | imbituba
# Processing Record 26 of Set 6 | shelopugino
# Processing Record 27 of Set 6 | kihei
# Processing Record 28 of Set 6 | finschhafen
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | kavaratti
# Processing Record 31 of Set 6 | sur
# Processing Record 32 of Set 6 | upington
# Processing Record 33 of Set 6 | bandarbeyla
# Processing Record 34 of Set 6 | saint-augustin
# Processing Record 35 of Set 6 | verkh-neyvinskiy
# Processing Record 36 of Set 6 | kalianget
# Processing Record 37 of Set 6 | baruun-urt
# Processing Record 38 of Set 6 | yulara
# Processing Record 39 of Set 6 | treinta y tres
# Processing Record 40 of Set 6 | dalvik
# Processing Record 41 of Set 6 | araouane
# Processing Record 42 of Set 6 | estacion coahuila
# Processing Record 43 of Set 6 | chifeng
# Processing Record 44 of Set 6 | turukhansk
# Processing Record 45 of Set 6 | teguise
# Processing Record 46 of Set 6 | westport
# Processing Record 47 of Set 6 | antalaha
# Processing Record 48 of Set 6 | kasempa
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | morehead
# City not found. Skipping...tabiauea
# Processing Record 1 of Set 7 | tabiauea
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | turkistan
# Processing Record 4 of Set 7 | cap malheureux
# Processing Record 5 of Set 7 | traverse city
# Processing Record 6 of Set 7 | buchanan
# Processing Record 7 of Set 7 | dzerzhinsk
# City not found. Skipping...sorvag
# Processing Record 8 of Set 7 | sorvag
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | vanimo
# Processing Record 11 of Set 7 | port hedland
# Processing Record 12 of Set 7 | hazorasp
# Processing Record 13 of Set 7 | yelan
# Processing Record 14 of Set 7 | kavieng
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | san pedro de macoris
# City not found. Skipping...jabiru
# Processing Record 17 of Set 7 | jabiru
# Processing Record 18 of Set 7 | celestun
# Processing Record 19 of Set 7 | byron bay
# Processing Record 20 of Set 7 | tessalit
# Processing Record 21 of Set 7 | collie
# City not found. Skipping...juifang
# Processing Record 22 of Set 7 | juifang
# City not found. Skipping...maykain
# Processing Record 23 of Set 7 | maykain
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | coromandel
# Processing Record 26 of Set 7 | sao joao da barra
# City not found. Skipping...viligili
# Processing Record 27 of Set 7 | viligili
# City not found. Skipping...karaul
# Processing Record 28 of Set 7 | karaul
# Processing Record 29 of Set 7 | belle fourche
# Processing Record 30 of Set 7 | bria
# Processing Record 31 of Set 7 | mount isa
# Processing Record 32 of Set 7 | chake chake
# City not found. Skipping...toliary
# Processing Record 33 of Set 7 | toliary
# Processing Record 34 of Set 7 | esperance
# Processing Record 35 of Set 7 | chumikan
# Processing Record 36 of Set 7 | souillac
# City not found. Skipping...tsihombe
# Processing Record 37 of Set 7 | tsihombe
# Processing Record 38 of Set 7 | smyrna
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | nador
# City not found. Skipping...zolotinka
# Processing Record 41 of Set 7 | zolotinka
# Processing Record 42 of Set 7 | terrace
# Processing Record 43 of Set 7 | kudahuvadhoo
# Processing Record 44 of Set 7 | ojinaga
# Processing Record 45 of Set 7 | brainerd
# Processing Record 46 of Set 7 | dale
# Processing Record 47 of Set 7 | bosaso
# Processing Record 48 of Set 7 | kagal
# Processing Record 49 of Set 7 | ursulo galvan
# Processing Record 50 of Set 7 | ati
# Processing Record 1 of Set 8 | yumen
# Processing Record 2 of Set 8 | traralgon
# Processing Record 3 of Set 8 | urumqi
# Processing Record 4 of Set 8 | bilkha
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | pionerskiy
# City not found. Skipping...nguiu
# Processing Record 7 of Set 8 | nguiu
# Processing Record 8 of Set 8 | puerto escondido
# Processing Record 9 of Set 8 | cutro
# Processing Record 10 of Set 8 | abay
# Processing Record 11 of Set 8 | east london
# Processing Record 12 of Set 8 | harper
# Processing Record 13 of Set 8 | huarmey
# Processing Record 14 of Set 8 | sokolo
# Processing Record 15 of Set 8 | esterhazy
# Processing Record 16 of Set 8 | ostrovnoy
# Processing Record 17 of Set 8 | nuuk
# Processing Record 18 of Set 8 | tuni
# Processing Record 19 of Set 8 | sao gotardo
# Processing Record 20 of Set 8 | vanavara
# Processing Record 21 of Set 8 | salamiyah
# Processing Record 22 of Set 8 | long beach
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | pangody
# City not found. Skipping...vaitupu
# Processing Record 25 of Set 8 | vaitupu
# Processing Record 26 of Set 8 | maarianhamina
# Processing Record 27 of Set 8 | mongu
# City not found. Skipping...duz
# Processing Record 28 of Set 8 | duz
# City not found. Skipping...ondorhaan
# Processing Record 29 of Set 8 | ondorhaan
# Processing Record 30 of Set 8 | los llanos de aridane
# Processing Record 31 of Set 8 | yenagoa
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | benghazi
# Processing Record 34 of Set 8 | san jose de rio tinto
# Processing Record 35 of Set 8 | feijo
# Processing Record 36 of Set 8 | quatre cocos
# Processing Record 37 of Set 8 | codrington
# City not found. Skipping...tumannyy
# Processing Record 38 of Set 8 | tumannyy
# Processing Record 39 of Set 8 | aksarka
# Processing Record 40 of Set 8 | rexburg
# Processing Record 41 of Set 8 | changping
# Processing Record 42 of Set 8 | kieta
# Processing Record 43 of Set 8 | wajid
# City not found. Skipping...bargal
# Processing Record 44 of Set 8 | bargal
# Processing Record 45 of Set 8 | lazaro cardenas
# Processing Record 46 of Set 8 | coahuayana
# Processing Record 47 of Set 8 | cilegon
# City not found. Skipping...bocaranga
# Processing Record 48 of Set 8 | bocaranga
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | civita castellana
# Processing Record 1 of Set 9 | tura
# Processing Record 2 of Set 9 | windhoek
# Processing Record 3 of Set 9 | iracoubo
# Processing Record 4 of Set 9 | verkhnetulomskiy
# Processing Record 5 of Set 9 | marzuq
# Processing Record 6 of Set 9 | adelaide
# City not found. Skipping...jiddah
# Processing Record 7 of Set 9 | jiddah
# Processing Record 8 of Set 9 | saint george
# Processing Record 9 of Set 9 | nantucket
# Processing Record 10 of Set 9 | pringsewu
# Processing Record 11 of Set 9 | lima
# Processing Record 12 of Set 9 | zhigalovo
# Processing Record 13 of Set 9 | arden
# Processing Record 14 of Set 9 | port macquarie
# Processing Record 15 of Set 9 | peniche
# Processing Record 16 of Set 9 | medak
# Processing Record 17 of Set 9 | dhidhdhoo
# Processing Record 18 of Set 9 | matara
# Processing Record 19 of Set 9 | gusau
# Processing Record 20 of Set 9 | newnan
# Processing Record 21 of Set 9 | saravan
# Processing Record 22 of Set 9 | qaqortoq
# Processing Record 23 of Set 9 | abu samrah
# Processing Record 24 of Set 9 | twin falls
# Processing Record 25 of Set 9 | manturovo
# Processing Record 26 of Set 9 | cootamundra
# Processing Record 27 of Set 9 | hambantota
# Processing Record 28 of Set 9 | maine-soroa
# Processing Record 29 of Set 9 | hlatikulu
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | lashio
# Processing Record 32 of Set 9 | aiquile
# Processing Record 33 of Set 9 | pitimbu
# Processing Record 34 of Set 9 | sept-iles
# City not found. Skipping...chagda
# Processing Record 35 of Set 9 | chagda
# Processing Record 36 of Set 9 | salinas
# Processing Record 37 of Set 9 | marrakesh
# Processing Record 38 of Set 9 | belyy yar
# Processing Record 39 of Set 9 | isangel
# Processing Record 40 of Set 9 | asau
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | borgarnes
# Processing Record 43 of Set 9 | morant bay
# Processing Record 44 of Set 9 | sangar
# Processing Record 45 of Set 9 | tarauaca
# Processing Record 46 of Set 9 | narsaq
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | eskil
# Processing Record 50 of Set 9 | artena
# Processing Record 1 of Set 10 | iqaluit
# Processing Record 2 of Set 10 | ogaminana
# Processing Record 3 of Set 10 | eureka
# Processing Record 4 of Set 10 | norman wells
# Processing Record 5 of Set 10 | vila velha
# Processing Record 6 of Set 10 | nyurba
# Processing Record 7 of Set 10 | kirkwall
# Processing Record 8 of Set 10 | sovetskiy
# Processing Record 9 of Set 10 | katangli
# Processing Record 10 of Set 10 | nampula
# Processing Record 11 of Set 10 | carauari
# Processing Record 12 of Set 10 | popova
# Processing Record 13 of Set 10 | fortuna
# Processing Record 14 of Set 10 | sechura
# Processing Record 15 of Set 10 | batagay-alyta
# Processing Record 16 of Set 10 | burnie
# Processing Record 17 of Set 10 | rincon
# Processing Record 18 of Set 10 | parabel
# Processing Record 19 of Set 10 | gimli
# Processing Record 20 of Set 10 | vera cruz
# Processing Record 21 of Set 10 | geraldton
# Processing Record 22 of Set 10 | port hardy
# Processing Record 23 of Set 10 | dergachi
# Processing Record 24 of Set 10 | avera
# Processing Record 25 of Set 10 | hinton
# City not found. Skipping...riaba
# Processing Record 26 of Set 10 | riaba
# Processing Record 27 of Set 10 | saint-pierre
# Processing Record 28 of Set 10 | cumana
# Processing Record 29 of Set 10 | palauig
# Processing Record 30 of Set 10 | minab
# Processing Record 31 of Set 10 | ternate
# Processing Record 32 of Set 10 | shieli
# Processing Record 33 of Set 10 | rudnogorsk
# Processing Record 34 of Set 10 | mayumba
# Processing Record 35 of Set 10 | ibra
# Processing Record 36 of Set 10 | muros
# Processing Record 37 of Set 10 | port keats
# Processing Record 38 of Set 10 | tammisaari
# Processing Record 39 of Set 10 | berlevag
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | san carlos de bariloche
# Processing Record 43 of Set 10 | nouakchott
# Processing Record 44 of Set 10 | bara
# Processing Record 45 of Set 10 | ribnitz-damgarten
# Processing Record 46 of Set 10 | maniitsoq
# Processing Record 47 of Set 10 | ulladulla
# Processing Record 48 of Set 10 | soto la marina
# Processing Record 49 of Set 10 | anloga
# Processing Record 50 of Set 10 | haines junction
# Processing Record 1 of Set 11 | kokrajhar
# Processing Record 2 of Set 11 | wanaka
# Processing Record 3 of Set 11 | hobyo
# Processing Record 4 of Set 11 | vangaindrano
# Processing Record 5 of Set 11 | cobija
# Processing Record 6 of Set 11 | inirida
# Processing Record 7 of Set 11 | acajutla
# Processing Record 8 of Set 11 | pimenta bueno
# Processing Record 9 of Set 11 | van buren
# Processing Record 10 of Set 11 | chicama
# Processing Record 11 of Set 11 | hommersak
# Processing Record 12 of Set 11 | auburndale
# Processing Record 13 of Set 11 | hualmay
# Processing Record 14 of Set 11 | natal
# Processing Record 15 of Set 11 | aripuana
# Processing Record 16 of Set 11 | moron
# Processing Record 17 of Set 11 | norderstedt
# City not found. Skipping...saleaula
# Processing Record 18 of Set 11 | saleaula
# Processing Record 19 of Set 11 | charters towers
# Processing Record 20 of Set 11 | saint anthony
# Processing Record 21 of Set 11 | coachella
# City not found. Skipping...tarudant
# Processing Record 22 of Set 11 | tarudant
# Processing Record 23 of Set 11 | lensk
# Processing Record 24 of Set 11 | edd
# Processing Record 25 of Set 11 | fare
# Processing Record 26 of Set 11 | tomatlan
# Processing Record 27 of Set 11 | munchberg
# Processing Record 28 of Set 11 | farah
# Processing Record 29 of Set 11 | tahta
# Processing Record 30 of Set 11 | polovinnoye
# Processing Record 31 of Set 11 | seydi
# Processing Record 32 of Set 11 | sao jose da coroa grande
# Processing Record 33 of Set 11 | gat
# Processing Record 34 of Set 11 | ilulissat
# Processing Record 35 of Set 11 | rosarito
# Processing Record 36 of Set 11 | regidor
# Processing Record 37 of Set 11 | quesnel
# Processing Record 38 of Set 11 | kerema
# Processing Record 39 of Set 11 | komsomolskiy
# Processing Record 40 of Set 11 | alice springs
# Processing Record 41 of Set 11 | coquimbo
# Processing Record 42 of Set 11 | marawi
# Processing Record 43 of Set 11 | port augusta
# Processing Record 44 of Set 11 | atar
# Processing Record 45 of Set 11 | gushikawa
# Processing Record 46 of Set 11 | altay
# Processing Record 47 of Set 11 | manjacaze
# Processing Record 48 of Set 11 | ginda
# Processing Record 49 of Set 11 | amga
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | sarankhola
# Processing Record 2 of Set 12 | san
# Processing Record 3 of Set 12 | krasnovishersk
# Processing Record 4 of Set 12 | pulaski
# Processing Record 5 of Set 12 | bolshaya martynovka
# Processing Record 6 of Set 12 | iranshahr
# Processing Record 7 of Set 12 | olinda
# Processing Record 8 of Set 12 | atikokan
# Processing Record 9 of Set 12 | kahului
# Processing Record 10 of Set 12 | tarrafal
# Processing Record 11 of Set 12 | nawashahr
# Processing Record 12 of Set 12 | wanning
# Processing Record 13 of Set 12 | nioro
# Processing Record 14 of Set 12 | kapit
# Processing Record 15 of Set 12 | san pedro de ycuamandiyu
# Processing Record 16 of Set 12 | taganak
# Processing Record 17 of Set 12 | mbarara
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | portland
# Processing Record 20 of Set 12 | kazachinskoye
# City not found. Skipping...gazni
# Processing Record 21 of Set 12 | gazni
# Processing Record 22 of Set 12 | oudenburg
# Processing Record 23 of Set 12 | andros town
# Processing Record 24 of Set 12 | salinopolis
# Processing Record 25 of Set 12 | broome
# Processing Record 26 of Set 12 | terney
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | kayerkan
# Processing Record 30 of Set 12 | baker city
# Processing Record 31 of Set 12 | dingle
# Processing Record 32 of Set 12 | gidole
# Processing Record 33 of Set 12 | gacheta
# Processing Record 34 of Set 12 | mareeba
# Processing Record 35 of Set 12 | vila franca do campo
# Processing Record 36 of Set 12 | fukue
# City not found. Skipping...manzil tamim
# Processing Record 37 of Set 12 | manzil tamim
# Processing Record 38 of Set 12 | kailua
# Processing Record 39 of Set 12 | haysville
# Processing Record 40 of Set 12 | kamaishi
# Processing Record 41 of Set 12 | sainte-marie
# Processing Record 42 of Set 12 | primorsk
# Processing Record 43 of Set 12 | xambioa
# Processing Record 44 of Set 12 | smithers
# City not found. Skipping...tunduru
# Processing Record 45 of Set 12 | tunduru
# Processing Record 46 of Set 12 | khandbari
# Processing Record 47 of Set 12 | waipawa
# Processing Record 48 of Set 12 | russell
# Processing Record 49 of Set 12 | leshukonskoye
# Processing Record 50 of Set 12 | marsabit
# Processing Record 1 of Set 13 | grand gaube
# Processing Record 2 of Set 13 | acapulco
# Processing Record 3 of Set 13 | whitehorse
# Processing Record 4 of Set 13 | kamariotissa
# City not found. Skipping...paradwip
# Processing Record 5 of Set 13 | paradwip
# Processing Record 6 of Set 13 | puka
# Processing Record 7 of Set 13 | nago
# Processing Record 8 of Set 13 | soure
# Processing Record 9 of Set 13 | vao
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | praia
# Processing Record 12 of Set 13 | sanary-sur-mer
# Processing Record 13 of Set 13 | guiyang
# Processing Record 14 of Set 13 | tuatapere
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | boyolangu
# Processing Record 17 of Set 13 | kolpashevo
# Processing Record 18 of Set 13 | meadow lake
# Processing Record 19 of Set 13 | yacuiba
# Processing Record 20 of Set 13 | silver city
# Processing Record 21 of Set 13 | hirara
# Processing Record 22 of Set 13 | quang ngai
# Processing Record 23 of Set 13 | the valley
# Processing Record 24 of Set 13 | talcahuano
# Processing Record 25 of Set 13 | deputatskiy
# City not found. Skipping...yusva
# Processing Record 26 of Set 13 | yusva
# Processing Record 27 of Set 13 | buin
# Processing Record 28 of Set 13 | gunjur
# Processing Record 29 of Set 13 | xiangxiang
# Processing Record 30 of Set 13 | santa fe
# Processing Record 31 of Set 13 | morondava
# Processing Record 32 of Set 13 | wuwei
# Processing Record 33 of Set 13 | sembe
# Processing Record 34 of Set 13 | kasungu
# Processing Record 35 of Set 13 | mbanza-ngungu
# Processing Record 36 of Set 13 | mitu
# Processing Record 37 of Set 13 | pyaozerskiy
# Processing Record 38 of Set 13 | pangoa
# Processing Record 39 of Set 13 | aravissos
# Processing Record 40 of Set 13 | hovd
# Processing Record 41 of Set 13 | adre
# Processing Record 42 of Set 13 | verkhnevilyuysk
# Processing Record 43 of Set 13 | katrineholm
# Processing Record 44 of Set 13 | adrar
# Processing Record 45 of Set 13 | lakatoro
# Processing Record 46 of Set 13 | altamira
# Processing Record 47 of Set 13 | evensk
# Processing Record 48 of Set 13 | calamar
# Processing Record 49 of Set 13 | prachuap khiri khan
# Processing Record 50 of Set 13 | parakou
# Processing Record 1 of Set 14 | warrington
# Processing Record 2 of Set 14 | leh
# Processing Record 3 of Set 14 | palmital
# Processing Record 4 of Set 14 | padang
# Processing Record 5 of Set 14 | newport
# Processing Record 6 of Set 14 | halifax
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | smolensk
# Processing Record 9 of Set 14 | new waterford
# Processing Record 10 of Set 14 | kingsville
# Processing Record 11 of Set 14 | nova olimpia
# Processing Record 12 of Set 14 | road town
# Processing Record 13 of Set 14 | kirillov
# Processing Record 14 of Set 14 | port moresby
# Processing Record 15 of Set 14 | tecalitlan
# City not found. Skipping...galiwinku
# Processing Record 16 of Set 14 | galiwinku
# Processing Record 17 of Set 14 | mitsamiouli
# Processing Record 18 of Set 14 | jiblah
# Processing Record 19 of Set 14 | novoagansk
# Processing Record 20 of Set 14 | atasu
# Processing Record 21 of Set 14 | kunming
# Processing Record 22 of Set 14 | taltal
# Processing Record 23 of Set 14 | mackay
# Processing Record 24 of Set 14 | mahibadhoo
# Processing Record 25 of Set 14 | yishui
# Processing Record 26 of Set 14 | koygorodok
# Processing Record 27 of Set 14 | effingham
# Processing Record 28 of Set 14 | karpogory
# City not found. Skipping...ho
# Processing Record 29 of Set 14 | ho
# Processing Record 30 of Set 14 | olga
# Processing Record 31 of Set 14 | tevriz
# Processing Record 32 of Set 14 | elizabeth city
# Processing Record 33 of Set 14 | havelock
# Processing Record 34 of Set 14 | gouvy
# Processing Record 35 of Set 14 | zhangzhou
# Processing Record 36 of Set 14 | itaituba
# Processing Record 37 of Set 14 | perth
# Processing Record 38 of Set 14 | keelung
# Processing Record 39 of Set 14 | gorontalo
# Processing Record 40 of Set 14 | saurimo
# Processing Record 41 of Set 14 | kyra
# Processing Record 42 of Set 14 | oussouye
# Processing Record 43 of Set 14 | okakarara
# Processing Record 44 of Set 14 | port-gentil
# Processing Record 45 of Set 14 | santo antonio do leverger
# Processing Record 46 of Set 14 | necochea
# Processing Record 47 of Set 14 | havre-saint-pierre
# Processing Record 48 of Set 14 | santander
# Processing Record 49 of Set 14 | tommot
# Processing Record 50 of Set 14 | honiara
# City not found. Skipping...karkaralinsk
# Processing Record 1 of Set 15 | karkaralinsk
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | ryotsu
# Processing Record 4 of Set 15 | linkoping
# Processing Record 5 of Set 15 | bahia blanca
# Processing Record 6 of Set 15 | yzeure
# Processing Record 7 of Set 15 | abu zabad
# Processing Record 8 of Set 15 | vilyuysk
# Processing Record 9 of Set 15 | aitape
# City not found. Skipping...la gaulette
# Processing Record 10 of Set 15 | la gaulette
# Processing Record 11 of Set 15 | shingu
# Processing Record 12 of Set 15 | san juan
# Processing Record 13 of Set 15 | daru
# Processing Record 14 of Set 15 | magadan
# City not found. Skipping...louisbourg
# Processing Record 15 of Set 15 | louisbourg
# Processing Record 16 of Set 15 | batsfjord
# City not found. Skipping...meyungs
# Processing Record 17 of Set 15 | meyungs
# Processing Record 18 of Set 15 | alihe
# Processing Record 19 of Set 15 | hay river
# Processing Record 20 of Set 15 | madarounfa
# Processing Record 21 of Set 15 | san quintin
# Processing Record 22 of Set 15 | muroto
# Processing Record 23 of Set 15 | yeppoon
# Processing Record 24 of Set 15 | anupgarh
# Processing Record 25 of Set 15 | calabozo
# Processing Record 26 of Set 15 | gravelbourg
# Processing Record 27 of Set 15 | lubango
# City not found. Skipping...kamenskoye
# Processing Record 28 of Set 15 | kamenskoye
# Processing Record 29 of Set 15 | batemans bay
# Processing Record 30 of Set 15 | ucluelet
# Processing Record 31 of Set 15 | hoa binh
# Processing Record 32 of Set 15 | pop
# Processing Record 33 of Set 15 | cayenne
# City not found. Skipping...andarab
# Processing Record 34 of Set 15 | andarab
# Processing Record 35 of Set 15 | anzio
# Processing Record 36 of Set 15 | lumby
# Processing Record 37 of Set 15 | georgiyevka
# Processing Record 38 of Set 15 | ous
# Processing Record 39 of Set 15 | paramirim
# Processing Record 40 of Set 15 | izhma
# City not found. Skipping...appiano
# Processing Record 41 of Set 15 | appiano
# Processing Record 42 of Set 15 | kungurtug
# Processing Record 43 of Set 15 | emerald
# Processing Record 44 of Set 15 | jalu
# Processing Record 45 of Set 15 | dubbo
# Processing Record 46 of Set 15 | rondonopolis
# Processing Record 47 of Set 15 | klaksvik
# Processing Record 48 of Set 15 | bereda
# Processing Record 49 of Set 15 | chongwe
# Processing Record 50 of Set 15 | ulaangom
# Processing Record 1 of Set 16 | oriximina
# Processing Record 2 of Set 16 | chabahar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0      lorengau      PG  2021-09-28 01:10:33  -2.0226  147.2712     85.50
# 1          lebu      CL  2021-09-28 01:14:17 -37.6167  -73.6500     48.31
# 2        ambulu      ID  2021-09-28 01:14:18  -8.3450  113.6058     80.22
# 3          chuy      UY  2021-09-28 01:14:18 -33.6971  -53.4616     57.25
# 4     upernavik      GL  2021-09-28 01:09:22  72.7868  -56.1549     25.07
# 5        avarua      CK  2021-09-28 01:14:19 -21.2078 -159.7750     80.65
# 6        hasaki      JP  2021-09-28 01:14:19  35.7333  140.8333     75.29
# 7  port lincoln      AU  2021-09-28 01:14:20 -34.7333  135.8667     68.07
# 8         airai      TL  2021-09-28 01:14:20  -8.9266  125.4092     77.05
# 9        tutoia      BR  2021-09-28 01:14:21  -2.7619  -42.2744     79.81
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        65          73        8.19       broken clouds
# 1        82          98       14.45     overcast clouds
# 2        68          16        4.79          few clouds
# 3        96         100        7.18          light rain
# 4        57          73        4.14       broken clouds
# 5        74          75       10.36       broken clouds
# 6        59          66       14.34       broken clouds
# 7        46          55        3.91       broken clouds
# 8        33          16        3.11          few clouds
# 9        84          38       12.15    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
